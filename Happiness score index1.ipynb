# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("happiness_score_dataset.csv")
df
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# we have 158 rows and 12 columns in dataset

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [raw]
# Happiness score is dependant variable - Float
# Country is an unique value like a primary key and that has no part in determining the dependant variable - Object
# Region is not dependent or independent variable to be considered for calculation - object
# Happiness Rank is derived from the Happiness score so not needed for calculation- int
# Economy (GDP per Capita),Family ,Health (Life Expectancy) ,Freedom,Trust (Government Corruption),Generosity,
# Dystopia Residual,Standard Error are dependant variables - Float

# %% [markdown]
# Target Variable - Happiness Score
#
#
# Independent variables - Economy (GDP per Capita) ,Family, Health (Life Expectancy) ,Freedom ,
# Trust (Government Corruption),Generosity,Dystopia Residual

# %%
df['Happiness Score'].unique()
# Out:
# array([7.587, 7.561, 7.527, 7.522, 7.427, 7.406, 7.378, 7.364, 7.286,
#        7.284, 7.278, 7.226, 7.2  , 7.187, 7.119, 6.983, 6.946, 6.94 ,
#        6.937, 6.901, 6.867, 6.853, 6.81 , 6.798, 6.786, 6.75 , 6.67 ,
#        6.611, 6.575, 6.574, 6.505, 6.485, 6.477, 6.455, 6.411, 6.329,
#        6.302, 6.298, 6.295, 6.269, 6.168, 6.13 , 6.123, 6.003, 5.995,
#        5.987, 5.984, 5.975, 5.96 , 5.948, 5.89 , 5.889, 5.878, 5.855,
#        5.848, 5.833, 5.828, 5.824, 5.813, 5.791, 5.77 , 5.759, 5.754,
#        5.716, 5.709, 5.695, 5.689, 5.605, 5.589, 5.548, 5.477, 5.474,
#        5.429, 5.399, 5.36 , 5.332, 5.286, 5.268, 5.253, 5.212, 5.194,
#        5.192, 5.14 , 5.129, 5.124, 5.123, 5.102, 5.098, 5.073, 5.057,
#        5.013, 5.007, 4.971, 4.959, 4.949, 4.898, 4.885, 4.876, 4.874,
#        4.867, 4.857, 4.839, 4.8  , 4.788, 4.786, 4.739, 4.715, 4.694,
#        4.686, 4.681, 4.677, 4.642, 4.633, 4.61 , 4.571, 4.565, 4.55 ,
# ...

# %% [markdown]
# As the target vaiable has more than 2 values so this is Regression problem

# %% [markdown]
# # Regression Problem

# %% [markdown]
# Check Nan Values

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# No Null values

# %%
df['Happiness Score'].value_counts()
# Out:
# 5.192    2
# 4.642    1
# 5.098    1
# 5.129    1
# 5.889    1
#         ..
# 4.252    1
# 4.633    1
# 3.931    1
# 7.200    1
# 6.750    1
# Name: Happiness Score, Length: 157, dtype: int64

# %%
df.loc[df['Happiness Score']== " "]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
df.loc[df['Happiness Score']== " "].sum()
# Out:
# Country                          0.0
# Region                           0.0
# Happiness Rank                   0.0
# Happiness Score                  0.0
# Standard Error                   0.0
# Economy (GDP per Capita)         0.0
# Family                           0.0
# Health (Life Expectancy)         0.0
# Freedom                          0.0
# Trust (Government Corruption)    0.0
# Generosity                       0.0
# Dystopia Residual                0.0
# dtype: float64

# %% [markdown]
# # EDA

# %% [markdown]
# As there are all the columns more than 2 unique value class imbalance can be avoided

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

sns.distplot(df['Happiness Score'], kde=True)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %%
sns.distplot(df['Economy (GDP per Capita)'], kde=True)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df['Family'], kde=True)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df['Health (Life Expectancy)'], kde=True)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df['Freedom'], kde=True)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df['Trust (Government Corruption)'], kde=True)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df['Generosity'], kde=True)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df['Dystopia Residual'], kde=True)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %% [markdown]
# All data except  is 'Dystopia Residual' is not normally distributed so cant consider mean value can consider
# only median value
# All independent variable except 'Dystopia Residual' has skewness

# %% [markdown]
# BOX plot

# %%
sns.boxplot(df['Standard Error'])
# Out:
# <AxesSubplot:xlabel='Standard Error'>

# %%
sns.boxplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)'>

# %%
sns.boxplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family'>

# %%
sns.boxplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom'>

# %%
sns.boxplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)'>

# %%
sns.boxplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity'>

# %%
sns.boxplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual'>

# %% [markdown]
# Standard Error,Family,Standard Error,Family,Generosity,Dystopia Residual columns have Outliers

# %% [markdown]
# # Encoding

# %%
df1=df

# %%
df1
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df1.columns:
    if df1[i].dtypes=="object":
        df1[i]=enc.fit_transform(df1[i].values.reshape(-1,1))

# %%
df1
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153    118.0     8.0             154            3.465         0.03464
# 154     13.0     8.0             155            3.340         0.03656
# 155    136.0     4.0             156            3.006         0.05015
# 156     21.0     8.0             157            2.905         0.08658
# 157    141.0     8.0             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153    118.0     8.0             154            3.465         0.03464
# 154     13.0     8.0             155            3.340         0.03656
# 155    136.0     4.0             156            3.006         0.05015
# 156     21.0     8.0             157            2.905         0.08658
# 157    141.0     8.0             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# Describe the dataset:¶

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# ...

# %%
df.dtypes
# Out:
# Country                          float64
# Region                           float64
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
sns.pairplot(df1, hue='Happiness Score',diag_kind="kde")

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[8,7])
plt.title('Comparison between Happiness Score and Economy ')
sns.scatterplot(df['Happiness Score'],df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:title={'center':'Comparison between Happiness Score and Economy '}, xlabel='Happiness Score', ylabel='Economy (GDP per Capita)'>

# %%
plt.figure(figsize=[8,7])
plt.title('Comparison between Economy (GDP per Capita) and Family ')
sns.scatterplot(df1['Economy (GDP per Capita)'],df1['Family'],hue=df1['Happiness Score'])
# Out:
# <AxesSubplot:title={'center':'Comparison between Economy (GDP per Capita) and Family '}, xlabel='Economy (GDP per Capita)', ylabel='Family'>

# %%
plt.figure(figsize=[8,7])
plt.title('Comparison between Health and Family ')
sns.scatterplot(df1['Health (Life Expectancy)'],df1['Family'],hue=df1['Happiness Score'])
# Out:
# <AxesSubplot:title={'center':'Comparison between Health and Family '}, xlabel='Health (Life Expectancy)', ylabel='Family'>

# %%
plt.figure(figsize=[8,7])
plt.title('Freedom  and Trust (Government Corruption)  ')
sns.scatterplot(df1['Trust (Government Corruption)'],df1['Freedom'],hue=df1['Happiness Score'])
# Out:
# <AxesSubplot:title={'center':'Freedom  and Trust (Government Corruption)  '}, xlabel='Trust (Government Corruption)', ylabel='Freedom'>

# %% [markdown]
# # Multi collinearity Check

# %%
cor=df.corr()
cor
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
fig, ax_size = plt.subplots(figsize=(14,12))
sns.heatmap(cor,annot=True,ax=ax_size,linecolor='r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore

z=np.abs(zscore(df))

new_df=df1(z<3).all(axis=1)]

# %%
new_df.shape
# Out:
# (149, 12)

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# Outlier removal calculation
# 158-149 = 9
# 9/158= 5.69%
# This outlier removal is less than 8% hence  considering the new df

# %% [markdown]
# # Variance Inflation Factor to find multi collinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = new_df.columns

# %%
    vif_data["VIF"] = [variance_inflation_factor(new_df.values, i)
                              for i in range(len(new_df.columns))]
    print(vif_data)
# Out:
#                           feature           VIF
# 0                         Country  4.167459e+00
# 1                          Region  5.642197e+00
# 2                  Happiness Rank  5.787757e+00
# 3                 Happiness Score  4.171813e+08
# 4                  Standard Error  1.374816e+01
# 5        Economy (GDP per Capita)  1.213265e+07
# 6                          Family  1.467887e+07
# 7        Health (Life Expectancy)  6.355228e+06
# 8                         Freedom  2.787275e+06
# 9   Trust (Government Corruption)  4.414145e+05
# 10                     Generosity  9.225968e+05
# 11              Dystopia Residual  6.484502e+07

# %% [markdown]
# Since Generosity has value near to 10 we shall drop this column

# %%
new_df.drop(['Generosity'],axis=1,inplace=True)

# %%
new_df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 150     66.0     8.0             151            3.655         0.05141
# 151     20.0     8.0             152            3.587         0.04324
# 152      0.0     7.0             153            3.575         0.03084
# 154     13.0     8.0             155            3.340         0.03656
# 156     21.0     8.0             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# # Removing skewness

# %%
new_df.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Dystopia Residual               -0.021144
# dtype: float64

# %% [markdown]
# # Define Dependant and independent variable

# %%
x=new_df.drop('Happiness Score',axis=1)
y=new_df['Happiness Score']

# %% [markdown]
# # Scaling the data using Min-Max Scaler:¶

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20, random_state=10)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.9953104438883872

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls = Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls = ls.predict(x_test)

lss = r2_score(y_test,pred_ls)
lss
# Out:
# 0.9858305870157149

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.41020085308865484

# %% [markdown]
# # Ensemble technique:¶

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse', 'mae'],'max_features':["auto", "sqrt", "log2"]}
rf =RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
rf= RandomForestRegressor(criterion="mse", max_features ="auto")
rf.fit(x_train, y_train)
rf.score(x_train, y_train)
pred_decision = rf.predict(x_test)

rfs = r2_score(y_test,pred_decision)
print('R2 Score:',rfs*100)

rfscore = cross_val_score(rf,x,y,cv=5)
rfc = rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 99.64383178881724
# Cross Val Score: -176.1546920374903

# %%
train, validation = train_test_split(df, test_size=0.50, random_state = 5)

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
# create dataset
X, y = make_classification(n_samples=10, n_features=20, n_informative=15, n_redundant=5, random_state=1)
# prepare the cross-validation procedure
cv = KFold(n_splits=10, random_state=1, shuffle=True)
# create model
model = LogisticRegression()
# evaluate model
scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# report performance
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# Accuracy: 0.900 (0.300)

# %% [markdown]
# This model is 90%

# %%
import pickle
filename = 'happyindex.pkl'
pickle.dump(rf, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('happyindex.pkl', 'rb'))
result = loaded_model.score(x_test, y_test)
print(result)
# Out:
# 0.9964383178881724

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=["Predicted","Orginal"])

# %%
conclusion
# Out:
#                 0        1       2        3        4       5        6   \
# Predicted  5.18077  3.98099  7.2074  5.03855  5.85531  5.8083  5.77697
# Orginal    5.18077  3.98099  7.2074  5.03855  5.85531  5.8083  5.77697
#
#                7        8        9   ...       20       21       22       23  \
# Predicted  5.1474  6.10031  3.59704  ...  5.33413  4.50064  5.82083  6.80436
# Orginal    5.1474  6.10031  3.59704  ...  5.33413  4.50064  5.82083  6.80436
#
#                 24       25       26       27       28       29
# Predicted  5.46814  7.47757  5.10217  3.86784  4.84904  5.05942
# Orginal    5.46814  7.47757  5.10217  3.86784  4.84904  5.05942
#
# [2 rows x 30 columns]

# %% [markdown]
# Predicted=Original

# %%
from scipy.stats import sem
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot
 
# evaluate a model with a given number of repeats
def evaluate_model(X, y, repeats):
	# prepare the cross-validation procedure
	cv = RepeatedKFold(n_splits=10, n_repeats=repeats, random_state=1)
	# create model
	model = LogisticRegression()
	# evaluate model
	scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
	return scores
 
# create dataset
X, y = make_classification(n_samples=100, n_features=20, n_informative=15, n_redundant=5, random_state=1)
# configurations to test
repeats = range(1,16)
results = list()
for r in repeats:
	# evaluate using a given number of repeats
	scores = evaluate_model(X, y, r)
	# summarize
	print('>%d mean=%.4f se=%.3f' % (r, mean(scores), sem(scores)))
	# store
	results.append(scores)
# plot the results
pyplot.boxplot(results, labels=[str(r) for r in repeats], showmeans=True)
pyplot.show()
# Out:
# >1 mean=0.8500 se=0.043
# >2 mean=0.8350 se=0.035
# >3 mean=0.8167 se=0.025
# >4 mean=0.8175 se=0.021
# >5 mean=0.8100 se=0.017
# >6 mean=0.8100 se=0.015
# >7 mean=0.8086 se=0.014
# >8 mean=0.8100 se=0.013
# >9 mean=0.8100 se=0.013
# >10 mean=0.8100 se=0.012
# >11 mean=0.8064 se=0.012
# >12 mean=0.8058 se=0.011
# >13 mean=0.8077 se=0.011
# >14 mean=0.8050 se=0.011
# >15 mean=0.8053 se=0.011

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=["Predicted","Orginal"])

# %%
conclusion
# Out:
#                 0        1       2        3        4       5        6   \
# Predicted  5.18077  3.98099  7.2074  5.03855  5.85531  5.8083  5.77697
# Orginal    5.18077  3.98099  7.2074  5.03855  5.85531  5.8083  5.77697
#
#                7        8        9   ...       20       21       22       23  \
# Predicted  5.1474  6.10031  3.59704  ...  5.33413  4.50064  5.82083  6.80436
# Orginal    5.1474  6.10031  3.59704  ...  5.33413  4.50064  5.82083  6.80436
#
#                 24       25       26       27       28       29
# Predicted  5.46814  7.47757  5.10217  3.86784  4.84904  5.05942
# Orginal    5.46814  7.47757  5.10217  3.86784  4.84904  5.05942
#
# [2 rows x 30 columns]
